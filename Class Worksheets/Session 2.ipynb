# %% [markdown]
# Before we get started:
#
# * review how to run your code in the datalore notebook
# * review how to run your code in the homework notebooks
# * ensure everyone has opened the notebook and the table of contents

# %% [markdown]
# ## Review Question 1
#
# Print a message to the screen stating your favourite subject in school:

# %% [markdown]
# ## Review Question 2
#
# Ask the program user how they're doing, using the input() function.

# %% [markdown]
# # Outline
# Today, we're going to cover:
# * Strings
# * String methods

# %% [markdown]
# Last time, we learned about **variables**, which allow us to store important information on a computer. Today, we're going to learn about one variable type, called a string.

# %% [markdown]
# #Strings
# ##What's a String?
#
# A string is a variable type in python, that is useful when we want to work with words and sentences. For example, if you want to initialize your name as a variable, you can do it as a string:
#
# ```python
# name = 'Sarah'
# ```
# You can also do it this way:
# ```python
# name = "Sarah"
# ```
#
# Notice the use of the single quotation marks (' ') vs. the double quotation marks (" "). It doesn't matter which ones you use, as long as you **use the same type of quotation marks for defining your string on both ends**.
#
# A string is made up of characters, that are the individual letters. For example, the name Sarah is made up of the characters 'S', 'a', 'r', 'a', 'h'.
#
# You can imagine that each letter in a string is a building block, similar to Lego! Each Lego brick 🧱 is important for the final structure.

# %% [markdown]
# A string doesn't have to be just one word, it can also be a sentence:
# ```python
# greeting = 'hello world!'
# ```
#
# In this string, the space that separates the word 'hello' from the word 'world!' is also a character.

# %% [markdown]
# ##Activity 1
# You want to build a structure with some others in the server. Initialize a string variable below with the name of one of the building blocks you can contribute to building the structure.
#
# Then, using one of the functions we learned last week, print the string to the screen.

# %%
#Complete code here
my_building_block =

# %% [markdown]
# ## Adding strings
# We can add strings together.
#
# **Adding** two strings together is useful if we want to create a sentence from separate words. For example:

# %%
s1 = 'hello'
s2 = 'world'
print(s1 + s2)

# %% [markdown]
# ## Activity 2
# What can we do to ensure that we print "hello world" instead?

# %% [markdown]
# ## Activity 3
# We want to print a list of all of the building blocks we have to build our structure. By adding the strings together the building block strings we initialized earlier, print a list of all the blocks we have.

# %%
print()

# %% [markdown]
# ##Slicing strings
#
# Sometimes we want to access part of a string, but not the entire string. We can **slice** into a string to access certain characters in the string.
#
# First, we want to determine how long strings are. Python counts each character in a string as one unit of length. To calculate the length of the string, we use the **len()** function:

# %%
s1 = 'happy'
string_length = len(s1)
print(string_length)

# %% [markdown]
# This indicates that there are 5 characters that make up the string `'happy'`

# %% [markdown]
# ## Activity 4
#
# Let's practice using the len() function. Initialize one string with your first name, another string with your last name, then find the length of each string.

# %%
first_name = ""
first_name_length = len(first_name)
print(first_name_length)

#Do something similar to the above for your last name

# %% [markdown]
# To access the first character in a string, we do:

# %%
s1 = 'happy'
print(s1[0])

# %% [markdown]
# Note the **index**, the number in the square brackets, is 0. So, to access the first character in the string, we use the zero<sup>th </sup> index.

# %% [markdown]
# ## Activity 5
#
# How can we access the second letter in a string?

# %%
s1 = 'happy'
print(s1[?])

# %% [markdown]
# >What happens if we pass index 5? Why does this happen?

# %%
s1 = 'happy'
print(s1[5])

# %% [markdown]
# What happens if we want to obtain more than one character from our string? We can slice the string into a chunk, just like a cake!
#
# We need to define a range of indices that we want to slice the string. In python, to represent a range, we use the ":" character. Let's try using this character to slice a string.

# %%
#Guess what the ouput would be
s1 = 'happy'
print(s1[0:3])

# %% [markdown]
# When we specify a range for slicing, it includes the first number, but does not include the outermost part of the range. For example, a slice of [1:4] will produce the following indices: 1, 2, and 3, but **not** 4!

# %% [markdown]
# ## Activity 6
# Your chatbot is trying to make friends! It asks someone "what is your name?" and they respond with "My name is Daniel". Slice this string to isolate the name "Daniel"

# %%
response = "My name is Daniel"
name = response[?:?]
print(name)
#your output should be "Daniel"

# %% [markdown]
# #String Methods
#
# Python provides several useful methods for manipulating strings, so that we don't have to write functions that do them!
#
# There are many methods, and we're going to familiarize ourselves with some of them. We can display all of the string methods by calling the help function:

# %%
help(str)

# %% [markdown]
# A method will take an already-initalized string, and return a **new value** once the operation is done. **The method does not modify the existing string**.
#
# To call a string method, you type the name of the string, followed by a '.', and the name of the method, and round brackets (). If the method requires an input, you type that input into the round brackets. For example:
# ```python
# s1 = 'happy'
# s2 = s1.capitalize()
# ```
#
# We're going to practice using some common string methods. We're going to cover:
# * casefold
# * endswith
# * count
# * rfind
#
# For help with other string methods, you can refer to https://www.w3schools.com/python/python_ref_string.asp

# %% [markdown]
# ### Casefold
#
# This method returns a string where all characters are lower case.

# %%
welcome = "Welcome To Python Programming a CHATBOT!"

welcome_method = welcome.casefold()

print("string before applying casefold method: " + welcome)
print("string after applying casefold method: " + welcome_method)

# %% [markdown]
# note several things in the example above:
# 1. the 'welcome' string did not change after calling the method
# 2. at the end of the method, we include round brackets (),

# %% [markdown]
# ### Endswith
#
# This method returns **True** if the string ends with the specified value (put in quotation marks), otherwise it returns **False**.
#
# Run the following examples to find out more about it!

# %%
statement = "would you like to play with me?"
question = statement.endswith("?")
print(question)

# %%
statement = "would you like to play with me?"
question = statement.endswith("!")
print(question)

# %% [markdown]
# #### Activity 7
# Your chatbot wants to determine if the program user is stating something or asking a question. For the following statements from the user, use the endswith() method to determine if the user is asking a question or not.
# 1. Hey, I'm Daniel.
# 2. How do you program a robot?
# 3. I can't stop thinking about this song!
#
# The first one is done for you.

# %%
is_question_1 = "Hey, I'm Daniel"
question = is_question_1.endswith("?")
print(question)

#Complete code similar to the above for the following two strings:
is_question_2 = "How do you program a robot?"

is_question_3 = "I can't stop thinking about this song!"

# %% [markdown]
# ### Count
#
# For our Turing test project, it is sometimes useful to search for certain instances of a specific word. For example, we could look for instances of the word 'name' in a response to identify that they are telling the machine their name. The count() method will return the number of times a string appears in another string

# %%
response = 'my name is Daniel'
print(response.count('name'))

# %% [markdown]
# #### Activity 8
# You are counting the number of each colour of lego pieces that you have in your lego set. You have a string that contains the colour of each of your pieces.
#
# Use the count() method to determine how many of each colour block you have (that is: blue, red, gree, yellow, and orange).
#
# The code for the blue blocks has already been written for you!

# %%
lego_blocks = 'blue, blue, red, red, red, red, green, yellow, orange, yellow, green, blue, red, blue, red, blue, green, yellow'

print(lego_blocks.count('blue'))
print(lego_blocks.count())

# %% [markdown]
# ### Rfind

# %% [markdown]
# When you're getting to know somebody, one of the first things you might do is ask for the person's name. Having obtained their name, you can respond with a personalized greeting, like the one displayed above.
#
# To extract their name, we need to predict the different ways they might introduce themselves. If your program asks someone what their name is, they will likely respond like this:
#
# 1. "My name is Daniel", or
# 2. "I'm Daniel", or
# 3. "Daniel"
#
# In cases 1 and 2, how could we isolate the name 'Daniel' from the rest of the response?
#
# The name is always the last word in the response, so if we can find the index of the last space, we can slice everything after that! using the rfind() method, we can find the rightmost index of the space character:

# %%
response = 'my name is Daniel'
space_index = response.rfind(' ')
#slice everything after that space
name = response[?:?]
print("nice to meet you " + name + "!")

# %% [markdown]
# So, using the rfind() method, and the ability to slice strings, we are able to print a personalized greeting to someone!

# %% [markdown]
# There are many other string methods in Python that we will not cover. For a list of all methods, and examples, visit [this link](https://www.w3schools.com/python/python_ref_string.asp)

# %% [markdown]
# ## Activity 9
#
# Now that we have been introduced to some basic features in Python, let's work on our chatbot!
#
# Write a program that:
# 1. Asks the user for their name, and obtains it as an input.
# 2. Prints a personalized greeting to the user. (hint: to do this, you will need to add strings together!)
# 3. Asks the user what their favourite game is.
# 4. Responds with the chatbot's favourite game.
#
# If you're done with this, what else can you add to your chatbot to make it sound more human?

# %%
# ask the user for their name using the input function. Be creative with how you ask!

# print a personalized greeting to the user

# ask the user what their favourite game is

# print a response with your chatbot's favourite game!

# %% [markdown]
# You've made it through the second session, and can program a talking chatbot! Head over to the homework to get some practice using strings 😃😃
