# %% [markdown]
# Congratulations! You've made it to the final session of the program! Today, we're going to continue working on our Turing machines, and present them at the end of the class!
#
# Remember, you are developing a Turing machine that mimics a human conversation. In this conversation, you are trying to meet a new friend and get to know them! Remember, you are trying to convince someone that your programmed machine is actually another person, and not a machine!

# %% [markdown]
# # Defining a Persona for your Machine

# %% [markdown]
# ![Screen Shot 2021-11-23 at 10.16.27 AM.png](data:image/png;base64,...)

# %% [markdown]
# In the first session, I introduced one of the first machines that was created to pass the Turing test: Eliza. What was special about it? For one, it had a name! This made it appear more human.

# %% [markdown]
# It's important to note that during a conversation, you don't want it to sound like the machine is interviewing the program user! A conversation should have **turn-taking**, where both individuals in the conversation are contributing and providing information. So, in our case, we need to create a persona for your machine. What is its name? How will it be feeling? What does it like to play with?

# %% [markdown]
# ![Screen Shot 2021-11-23 at 10.26.06 AM.png](data:image/png;base64,...)

# %% [markdown]
# As your machine asks questions, it needs to provide information about itself as well. Define some characteristics for your machine.

# %%
# define some characteristics for your machine, such as a name, age, etc.

# %% [markdown]
# # Creating a continuous conversation
#
# Now that we have the decision-making set, we want to mimic the back-and-forth process that occurs when we communicate with somebody else. For this, we can use a loop 🔃.
#
# Which loop (for loop or while loop) is best for this application?

# %%
discussion = 1
machine_response = "Hey! what's your name?"

while discussion == 1:
  #get input from user

  #using the if statements we defined earlier, make decisions about the input 
  # from the user 

  #when does the conversation end? How do you go about ending the conversation?

# %% [markdown]
# # Dealing with Unknown Responses from the Program User
# On some occasions our machine might run into a response from the program user that we didn't plan for. What sequence can we implement in those cases where the machine does not understand what the program user is saying? What do you politely say so that they can rephrase?

# %% [markdown]
# ![Screen Shot 2021-11-23 at 10.49.36 AM.png](data:image/png;base64,...)

# %% [markdown]
# # Transitioning between conversation topics
#
# You likely don't want your machine to only discuss one topic with the program user, so how do you go about transitioning from one topic of conversation to another?
#
# Modify your if statements so that once you finish talking about one topic, you transition smoothly to another (or you end the conversation!)

# %% [markdown]
# # Conversation Topics
#
# (If you have the time) We want our machine to be as robust as possible! For this to happen, our machine should be able to talk about many topics!
#
# Using a new **if statement**, create another conversation topic for your machine!

# %% [markdown]
# # Your Turing Machine 🤖 🖥 🧑

# %%
# define your machine's persona

# %%
# ask them about their name and respond by introducing yourself

# ask them about their age and respond with your age

# %%
# now that we have some basic information about them, we can start the conversation!
