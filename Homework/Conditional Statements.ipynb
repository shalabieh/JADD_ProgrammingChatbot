# %% [markdown]
# ## Question 1
#
# You are teaching your friend the sounds different animals make. You ask your friend to state the sound that a cow 🐄 makes.
#
# Using an if statement, determine if their response is correct. Fill in the blanks.
#
# hint: **if** your friend responds "moo" → they're correct!
#
# **else** → they are incorrect

# %%
# ask program user what is the sound a cow makes?
user_response = input("")

if user_response == "":
  print("")
else:
  print("")

# %% [markdown]
# ## Question 2
#
# Now, you want to test whether they know the sound a duck 🦆 makes. Similar to the program you wrote for question 1, determine whether your friend knows the sound a duck makes!

# %%
# ask program user what is the sound a duck makes?
user_response = input("")

if _______:
  print("")
else:
  print("")

# %% [markdown]
# ## Question 3
#
# Now, let's practice writing if statements when we have more than 2 possible conditions.
#
# Ask the program user for their favourite food 🍔 🍕 🌭 🌶. If it is the same as one of your top three favourite foods, print a message saying "that's my favourite too!"
#
# Fill in the blanks in the code below.

# %%
# insert your top three favourite foods in these string variables
top_favourite_food = ""
second_favourite_food = ""
third_favourite_food = ""

# ask user for their favourite food as input
user_favourite_food = input("what's your favourite food?")

# determine if their favourite food is one of your top 3, and print appropriate 
# response
if user_favourite_food == top_favourite_food:
  print("")
elif ______:
  print("")
elif _____:
  print("")
else:
  print("")

# %% [markdown]
# ## Question 4
#
# You want to ask your friend what their favourite colour of the rainbow 🌈 is, so that you can make them a card for their birthday!
#
# Write an if statement to determine what their favourite colour is, and formulate a response! Some of the code has been written for you as a starter. Complete the blanks, and add more `elif` statements.

# %%
# using the input() function, ask your friend what their favourite colour is
favourite_colour = input("")

# using an if statement, determine what their favourite colour is, and respond
# appropriately. 
# remember, there are 6 colours in the rainbow! So you should have a response 
# for all 6 colours!

if favourite_colour == "blue":
  print("")
elif favourite_colour == '':
  print("") #do this several more times to cover all the colours!

# %% [markdown]
# ## Question 5
#
# When working with strings, it can be useful to search for a specific word within a string. For example, if somebody says "I am happy", we can isolate the important feeling word from the phrase by looking for the word "happy".
#
# You ask your friend what their favourite colour is, and they may respond with "my favourite colour is blue".
#
# Modify your code from question 4, using **in**, determine what their favourite colour is and write a response.
#
# ☀hint: you need to modify your code that looks like this:
# ```python
# if feeling == "happy":
#   print("that's great!")
# ```
# to this:
# ```python
# if "happy" in feeling:
#   print("that's great!")
# ```

# %%
# copy your code from question 4 down here, and make modifications

# %% [markdown]
# ## Question 6
#
# To enter an an art competition 🎨, you need to either paint **or** sketch. Unfortunately, you cannot enter the competition if you do pottery.
# Write an if statement that asks what form of art a program user does, and determines if they can enter the competition.
#
# Some of the code has been written for you. Simply fill in the blanks.

# %%
art = input("what form of art do you do?")

if ____ or ______:
  print("")
else:
  print("")

# %% [markdown]
# ## Question 7
#
# For your birthday, your parents will buy you one present. This year, you really want a video game 🎮 or a comic book 📚, but you don't want a new shirt 👕.
#
# So:
#
# 🎮 **or** 📚 ➡ 😃
#
# 👕 ➡ 😞
#
# Write a conditional statement that prints how you feel depending on the present you get.
#
# Some of the code has been written for you. Simply fill in the blanks.

# %%
#write an input statement that gets information about the present you got
gift = input("what gift did you get? ")

#write an if statement that prints your reaction depending on the game you get
if ________ __ ________: # under what gift conditions will you be happy?
  print("")
elif _______: # under what gift conditions will you be sad?
  print("")

# %% [markdown]
# ## Question 8
#
# You work at a fast food restaurant and need to do the following tasks:
#
# 1. Ask the customer what they want to order
# 2. Prepare their food
# 3. Give them their food
#
# Write code that determines what they ordered, and tells them their order is finished.
#
# For example, if they say "I want a hamburger", your code should print "Your hamburger is ready"
#
# The items on the menu are:
# * hamburger
# * fries
# * hotdog
#
# Some of the code is already written. Simply fill in the blanks

# %%
order = input(_______)

if 'hamburger' in order:
  print("Your hamburger is ready")
elif _____ __ _____:
  print(_________)
elif _____ __ ______:
  print(_________)

# %% [markdown]
# ## Question 9
#
# Ask the program user for their favourite colour. If their favourite colour is the same as yours, print a statement to the screen telling them how awesome their favourite colour is.
#
# There are guides for writing the code, however, none of it has been written for you.

# %%
# Ask program user for their favourite colour

# Determine if it's the same as your favourite colour, and print appropriate 
# message to screen
