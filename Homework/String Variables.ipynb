# %% [markdown]
# ## Question 1
#
# You see the following code:
#
# ```python
# 'roblox' = favourite_game
# ```
#
# Will this generate an error? If yes, how can you fix this code so that it does not generate an error?

# %%
response = '' #@param {type:"string"}

# %% [markdown]
# If you think the code above will generate an error, rewrite the code below so that it does not generate an error:

# %% [markdown]
# ## Question 2
#
# Read the sentences below out loud. Create a string for each of the sentences below, and print them to the screen:
# <ol type= "a">
#   <li>When I am sad, I like talking to my friend.
#   <li>When I am happy, I smile.
#   <li>When I am angry, I like to sit by myself.
#   <li>I might feel angry because I am hungry.

# %%
# sentence a:
sentence_a = 
print()
# sentence b:
sentence_b = 
print()
# sentence c:
sentence_c = 
print()
# sentence d:
sentence_d = 
print()

# %% [markdown]
# ## Question 3
#
# For the following strings, print the length of each string by using the len() function.
#
# <ol type= "a">
#   <li>When I am sad, I like talking to my friend.
#   <li>When I am happy, I smile.
#   <li>When I am angry, I like to sit by myself.
#   <li>I might feel angry because I am hungry.
#   <li>I like Minecraft.

# %%
#a. the first question is done for you
s1 = "When I am sad, I like talking to my friend."
print(len(s1))
#b.

#c.

#d.

#e.

# %% [markdown]
# ## Question 4
# A string is initialized in Python:
# ```python
# greeting = 'see you later alligator!'
# ```
# Predict what the following code will output. If you are unsure, test the code and see what it outputs.
#
# <ol type = "a">
#   <li>
#
# `print(greeting[5])`
#
#   <li>
#
#   `print(greeting[0])`
#   <li>
#
#   `print(greeting[0:3])`
#   <li>
#
#   `print(greeting[:3])`
#   <li>
#
#   `print(greeting[14:])`

# %%
a = '' #@param {type:"string"}
b = '' #@param {type:"string"}
c = '' #@param {type:"string"}
d = '' #@param {type:"string"}
e = '' #@param {type:"string"}

# %%
# test the code for answers you're note sure about here
greeting = 'see you later alligator!'
#part a
print(greeting[5])

#part b

# %% [markdown]
# ## Question 5
#
# Strings can be added together to make longer strings. Create a program that:
# 1. Asks a user for their name and favourite toy using the input() function,
# 2. Creates a new string by **adding** strings obtained from the input (e.g., *Sarah* likes to play *Xbox*), and
# 3. Prints that string to the screen

# %%
name = input("")
toy = 
sentence = 
print()

# %% [markdown]
# ## Question 6
#
# Write code that slices into the following string:
#
# ```python
# greeting = 'see you later alligator!'
# ```
# to obtain the following words:
# <ol type = "a">
#   <li> see
#   <li>!
#   <li>alligator
#   <li>you
#
#
# The first question is done for you

# %%
greeting = 'see you later alligator!'
# a.
print(greeting[0:3])
# b.

# c.

# d.

# %% [markdown]
# ## Question 7
#
# We often use an exclamation mark (!) at the end of a sentence to describe that we are very excited!
#
# Write a program that:
# 1. Asks a program user how they are doing and takes their response as an input, using the input() function
# 2. Determines if they are excited based on whether they end their sentence with an exclamation (!) or not. Use the .endswith() string method to check for an exclamation mark at the end of the string.

# %%
# ask user for input on how they're doing

# determine if they're excited by checking for an exclamation at the end of their sentence

# %% [markdown]
# ## Question 8
#
# Write a program that asks the program user for their favourite food, and prints their favourite food onto the screen.
#
# Make sure that you're printing a meaningful sentence. So, if the user's response is 'hamburger', don't print 'hamburger', print 'your favourite food is a hamburger'.

# %% [markdown]
# ## Question 9
#
# Write a program that asks the program user for their favourite game, and prints their favourite game on the screen.
#
# Again, make sure you're printing a meaningful sentence!

# %% [markdown]
# ## Question 10
#
# Determine what the following string methods will return for each piece of code below:
#
# <ol type = "a">
#   <li>
#
# ` s1 = "I am feeling happy today!" `
#
# ` print(s1.count("happy"))`
#   <li>
#
# ` s1 = "I am feeling happy today!" `
#
# ` print(s1.endswith("!"))`
#   <li>
#
# ` s1 = "I am feeling happy today!" `
#
# ` print(s1.endswith("?"))`
#   <li>
#
# ` s1 = "I am feeling HAPPY today!" `
#
# ` print(s1.casefold())`

# %%
# a.

# b.

# c.

# d.

# %% [markdown]
# ## Question 11
#
# Determine the length of each of the following strings using the len() function. Then, print the length to the screen.
#
# <ol type = "a">
#   <li>
#
# I like playing Super Mario
#   <li>
#
# Tomatoes are delicious
#   <li>
#
# Tyrannosaurus Rex had tiny arms
#   <li>
#
# Penguins live in Antartica

# %%
# a.

# b.

# c.

# d.

# %% [markdown]
# ## Question 12
#
# Will the following code produce an error? If yes, why? How could you fix it?
#
# ```python
# game = 'Minecraft'
# print(game[9])
# ```

# %%
#@title 
answer = '' #@param {type:"string"}
#@markdown (don't forget to fix the code if it's wrong!)

# %%
# fix the code if it's wrong here

# %% [markdown]
# ## Question 13
#
# The following code is supposed to print "Mario and Luigi" to the screen:
# ```python
# brother1 = 'Mario'
# brother2 = 'Luigi'
# print(brother1 + 'and' + brother2)
# ```
#
# But instead, prints "MarioandLuigi". How can you fix the code above so that it prints "Mario and Luigi"?

# %% [markdown]
# ## Question 14
#
# Write a program that adds the letters 'ing' to the end of any input it receives from the program user, and prints this to the string. For example, if the program user inputs 'play', your program should modify this to 'playing' and print it.

# %% [markdown]
# ## Question 15
#
# Modify the following string:
# ```python
# my_day = 'my day is bad'
# ```
#
# to 'my day is good' by:
#
# 1. slicing the first part of the my_day string, then
# 2. adding the word 'good' to the end of the string.
# 3. Then, print this new string to the screen.
