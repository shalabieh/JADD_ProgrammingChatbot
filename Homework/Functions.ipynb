# %% [markdown]
# ## Question 1
#
# Write a function that takes two strings and combines them into one string.
#
# For example:
#
# ```python
# >>>combine_string('rain', 'bow')
# 'rainbow'
# ```

# %%
def combine_string(word_1: str, word_2: ____)-> str:
  '''
  takes two strings, and combines them into one string
  >>>combine_string('rain', 'bow)
  'rainbow'
  >>>combine_string('cat', 'fish')
  'catfish'
  >>>combine_string('black', 'board')
  'blackboard'
  '''
  #hint: you can use string addition here!
  add_string =   

  return add_string

# %%
# now test your function. Do you get the expected output?
combine_string('', '')

# %% [markdown]
# ## Question 2
#
# Write a function that takes a name and an age, and outputs a sentence.
#
# For example,
# ```python
# >>>name_age('Jake', '9')
# 'Jake is 9 years old'
# ```

# %%
def name_age(___:__, ____:__)-> str:
  '''
  add a description of what your program is doing here!
  don't forget to include examples!
  '''
  #hint: you need to do string addition!
  name_age_string = 

  return name_age_string

# %%
# now test your function. Do you get the expected output?
name_age('', '')

# %% [markdown]
# ## Question 3
#
# Write a function that determines what somebody is feeling.
#
# For example,
# ```python
# >>>input_string = 'I am feeling happy'
# >>>feeling(input_string)
# 'happy'
# ```
# or
# ```python
# >>>input_string = 'I am feeling sad'
# >>>feeling (input_string)
# 'sad'
# ```
#
# Your code should plan for the following feelings (and you can implement more if you want!)
# 1. happy
# 2. sad
# 3. bad
# 4. not bad
# 5. ecstatic
#
# (note: some of these are similar!)
#
# Make sure you fill in the blanks!

# %%
def feeling(___:__, ___:__)-> ___:
  '''

  '''
  #hint: you need to write an if statement here!

  return _______

# %%
# now test your function. Do you get the expected output?
test_string = ''
feeling(test_string)

# %% [markdown]
# ## Question 4
#
# You are programming a robot 🤖 that navigates a maze. If the robot detects an obstacle in its path, you want it to turn right ➡. Otherwise, you want it to continue moving straight.
#
# Write a function that takes as an input whether or not there is an obstacle in front of it, and decides on the next move for the robot.
#
# For example,
# ```python
# >>>robot_move('no obstacle')
# 'move forward'
# >>>robot_move('obstacle')
# 'turn right'
# ```

# %%
def robot_move()-> :
  '''

  '''

  return

# %%
# now test your function. Do you get the expected output?
print(robot_move('no obstacle'))
print(robot_move('obstacle'))

# %% [markdown]
# ## Question 5
#
# Now, you want your robot to be able to turn left and right. Write a function that takes one of the following inputs and outputs the corresponding robot movement.
#
# | Input            | Robot Movement    |
# |------------------|-------------------|
# | "no obstacle"    | continue straight |
# | "obstacle left"  | turn right        |
# | "obstacle right" | turn left         |
#
# For example,
# ```python
# >>>robot_move('obstacle left')
# 'turn right'
# ```

# %%
def robot_move()-> :
  '''

  '''

  return

# %%
# now test your function. Do you get the expected output?
print(robot_move('no obstacle'))
print(robot_move('obstacle left'))
print(robot_move('obstacle right'))

# %% [markdown]
# ## Question 6
#
# Write a function that gets somebody's first name and last name, and combines it into one string.
#
# Then, write code that takes as an input the user's first name, the user's last name, passes this through the function, and prints the function output.

# %%
def full_name()-> :
  '''

  '''

  return

# %%
# ask for first name, save to variable

# ask for last name, save to variable

# call the full_name function, pass the first and last names as inputs

# print the output from the full_name function
